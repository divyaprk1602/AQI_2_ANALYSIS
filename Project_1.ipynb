# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the dataset

data=pd.read_csv('AQI and Lat Long of Countries.csv')

# %%
data.head(10)


# Displays the first 10 rows of the dataset.
# Out:
#                     Country              City  AQI Value AQI Category
# 0        Russian Federation        Praskoveya         51     Moderate  \
# 1                    Brazil  Presidente Dutra         41         Good
# 2                    Brazil  Presidente Dutra         41         Good
# 3                     Italy   Priolo Gargallo         66     Moderate
# 4                    Poland         Przasnysz         34         Good
# 5  United States of America       Punta Gorda         54     Moderate
# 6  United States of America       Punta Gorda         54     Moderate
# 7                   Belgium             Puurs         64     Moderate
# 8        Russian Federation        Pyatigorsk         54     Moderate
# 9                     China           Qinzhou         68     Moderate
#
#    CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category
# 0             1            Good               36               Good  \
# 1             1            Good                5               Good
# 2             1            Good                5               Good
# 3             1            Good               39               Good
# 4             1            Good               34               Good
# 5             1            Good               14               Good
# 6             1            Good               14               Good
# 7             1            Good               29               Good
# 8             1            Good               41               Good
# 9             2            Good               68           Moderate
#
#    NO2 AQI Value NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category
# 0              0             Good               51           Moderate  \
# 1              1             Good               41               Good
# 2              1             Good               41               Good
# 3              2             Good               66           Moderate
# 4              0             Good               20               Good
# 5             11             Good               54           Moderate
# 6             11             Good               54           Moderate
# 7              7             Good               64           Moderate
# 8              1             Good               54           Moderate
# 9              1             Good               58           Moderate
#
#        lat       lng
# 0  44.7444   44.2031
# 1  -5.2900  -44.4900
# 2 -11.2958  -41.9869
# 3  37.1667   15.1833
# 4  53.0167   20.8833
# 5  16.1005  -88.8074
# 6  26.8941  -82.0513
# 7  51.0761    4.2803
# 8  44.0500   43.0667
# 9  21.9500  108.6167

# %% [markdown]
# ##   Cleaning Data and Preprocessing

# %%
data.drop_duplicates(subset=["City"],inplace=True)

# %%
data.head(4)
# Out:
#               Country              City  AQI Value AQI Category  CO AQI Value
# 0  Russian Federation        Praskoveya         51     Moderate             1  \
# 1              Brazil  Presidente Dutra         41         Good             1
# 3               Italy   Priolo Gargallo         66     Moderate             1
# 4              Poland         Przasnysz         34         Good             1
#
#   CO AQI Category  Ozone AQI Value Ozone AQI Category  NO2 AQI Value
# 0            Good               36               Good              0  \
# 1            Good                5               Good              1
# 3            Good               39               Good              2
# 4            Good               34               Good              0
#
#   NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category      lat      lng
# 0             Good               51           Moderate  44.7444  44.2031
# 1             Good               41               Good  -5.2900 -44.4900
# 3             Good               66           Moderate  37.1667  15.1833
# 4             Good               20               Good  53.0167  20.8833

# %%
data.reset_index()
# Out:
#        index                   Country              City  AQI Value
# 0          0        Russian Federation        Praskoveya         51  \
# 1          1                    Brazil  Presidente Dutra         41
# 2          3                     Italy   Priolo Gargallo         66
# 3          4                    Poland         Przasnysz         34
# 4          5  United States of America       Punta Gorda         54
# ...      ...                       ...               ...        ...
# 14224  16689                     China          Shaoguan        160
# 14225  16690  United States of America  Highland Springs         54
# 14226  16691                  Slovakia            Martin         71
# 14227  16693                    France            Sceaux         50
# 14228  16694  United States of America       Westerville         71
#
#       AQI Category  CO AQI Value CO AQI Category  Ozone AQI Value
# 0         Moderate             1            Good               36  \
# 1             Good             1            Good                5
# 2         Moderate             1            Good               39
# 3             Good             1            Good               34
# 4         Moderate             1            Good               14
# ...            ...           ...             ...              ...
# 14224    Unhealthy             3            Good              160
# 14225     Moderate             1            Good               34
# 14226     Moderate             1            Good               39
# 14227         Good             1            Good               20
# 14228     Moderate             1            Good               44
#
#       Ozone AQI Category  NO2 AQI Value NO2 AQI Category  PM2.5 AQI Value
# 0                   Good              0             Good               51  \
# 1                   Good              1             Good               41
# 2                   Good              2             Good               66
# 3                   Good              0             Good               20
# 4                   Good             11             Good               54
# ...                  ...            ...              ...              ...
# 14224          Unhealthy              1             Good               79
# 14225               Good              5             Good               54
# 14226               Good              1             Good               71
# 14227               Good              5             Good               50
# 14228               Good              2             Good               71
#
#       PM2.5 AQI Category      lat       lng
# 0               Moderate  44.7444   44.2031
# 1                   Good  -5.2900  -44.4900
# 2               Moderate  37.1667   15.1833
# 3                   Good  53.0167   20.8833
# 4               Moderate  16.1005  -88.8074
# ...                  ...      ...       ...
# 14224           Moderate  24.8011  113.5927
# 14225           Moderate  37.5516  -77.3285
# 14226           Moderate  49.0650   18.9219
# 14227               Good  48.7786    2.2906
# 14228           Moderate  40.1241  -82.9210
#
# [14229 rows x 15 columns]

# %%
data.reset_index(drop=True,inplace=True)

# %%
data.head(10)
# Out:
#                     Country              City  AQI Value AQI Category
# 0        Russian Federation        Praskoveya         51     Moderate  \
# 1                    Brazil  Presidente Dutra         41         Good
# 2                     Italy   Priolo Gargallo         66     Moderate
# 3                    Poland         Przasnysz         34         Good
# 4  United States of America       Punta Gorda         54     Moderate
# 5                   Belgium             Puurs         64     Moderate
# 6        Russian Federation        Pyatigorsk         54     Moderate
# 7                     China           Qinzhou         68     Moderate
# 8               Netherlands            Raalte         41         Good
# 9                    France           Raismes         59     Moderate
#
#    CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category
# 0             1            Good               36               Good  \
# 1             1            Good                5               Good
# 2             1            Good               39               Good
# 3             1            Good               34               Good
# 4             1            Good               14               Good
# 5             1            Good               29               Good
# 6             1            Good               41               Good
# 7             2            Good               68           Moderate
# 8             1            Good               24               Good
# 9             1            Good               30               Good
#
#    NO2 AQI Value NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category
# 0              0             Good               51           Moderate  \
# 1              1             Good               41               Good
# 2              2             Good               66           Moderate
# 3              0             Good               20               Good
# 4             11             Good               54           Moderate
# 5              7             Good               64           Moderate
# 6              1             Good               54           Moderate
# 7              1             Good               58           Moderate
# 8              6             Good               41               Good
# 9              4             Good               59           Moderate
#
#        lat       lng
# 0  44.7444   44.2031
# 1  -5.2900  -44.4900
# 2  37.1667   15.1833
# 3  53.0167   20.8833
# 4  16.1005  -88.8074
# 5  51.0761    4.2803
# 6  44.0500   43.0667
# 7  21.9500  108.6167
# 8  52.3833    6.2667
# 9  50.3892    3.4858

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14229 entries, 0 to 14228
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             13956 non-null  object
#  1   City                14229 non-null  object
#  2   AQI Value           14229 non-null  int64
#  3   AQI Category        14229 non-null  object
#  4   CO AQI Value        14229 non-null  int64
#  5   CO AQI Category     14229 non-null  object
#  6   Ozone AQI Value     14229 non-null  int64
#  7   Ozone AQI Category  14229 non-null  object
#  8   NO2 AQI Value       14229 non-null  int64
#  9   NO2 AQI Category    14229 non-null  object
#  10  PM2.5 AQI Value     14229 non-null  int64
#  11  PM2.5 AQI Category  14229 non-null  object
#  12  lat                 14229 non-null  float64
#  13  lng                 14229 non-null  float64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.5+ MB

# %% [markdown]
# ###   *Dataset Contains 14,229 rows and 14 columns.

# %%
data.columns
# Out:
# Index(['Country', 'City', 'AQI Value', 'AQI Category', 'CO AQI Value',
#        'CO AQI Category', 'Ozone AQI Value', 'Ozone AQI Category',
#        'NO2 AQI Value', 'NO2 AQI Category', 'PM2.5 AQI Value',
#        'PM2.5 AQI Category', 'lat', 'lng'],
#       dtype='object')

# %%
data.describe(include='all')
# Pandas describe() is used to view some basic statistical details like percentile, mean, std etc. 
# of a data frame or a series of numeric values.
# Out:
#                          Country        City     AQI Value AQI Category
# count                      13956       14229  14229.000000        14229  \
# unique                       174       14229           NaN            6
# top     United States of America  Praskoveya           NaN         Good
# freq                        2777           1           NaN         6670
# mean                         NaN         NaN     62.975824          NaN
# std                          NaN         NaN     43.313057          NaN
# min                          NaN         NaN      7.000000          NaN
# 25%                          NaN         NaN     38.000000          NaN
# 50%                          NaN         NaN     52.000000          NaN
# 75%                          NaN         NaN     69.000000          NaN
# max                          NaN         NaN    500.000000          NaN
#
#         CO AQI Value CO AQI Category  Ozone AQI Value Ozone AQI Category
# count   14229.000000           14229     14229.000000              14229  \
# unique           NaN               3              NaN                  5
# top              NaN            Good              NaN               Good
# freq             NaN           14227              NaN              13159
# mean        1.317450             NaN        32.532645                NaN
# std         1.970172             NaN        23.285521                NaN
# min         0.000000             NaN         0.000000                NaN
# 25%         1.000000             NaN        21.000000                NaN
# 50%         1.000000             NaN        30.000000                NaN
# 75%         1.000000             NaN        38.000000                NaN
# max       133.000000             NaN       222.000000                NaN
#
#         NO2 AQI Value NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category
# count    14229.000000            14229     14229.000000              14229  \
# unique            NaN                2              NaN                  6
# top               NaN             Good              NaN               Good
# freq              NaN            14220              NaN               6871
# mean         3.491812              NaN        59.624359                NaN
# std          5.634884              NaN        43.448684                NaN
# min          0.000000              NaN         0.000000                NaN
# 25%          0.000000              NaN        34.000000                NaN
# 50%          1.000000              NaN        51.000000                NaN
# 75%          4.000000              NaN        68.000000                NaN
# max         91.000000              NaN       500.000000                NaN
#
#                  lat           lng
# count   14229.000000  14229.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean       30.869726      1.009732
# std        23.042552     70.461845
# min       -54.801900   -171.750000
# 25%        17.769400    -71.515700
# 50%        39.235800      8.130000
# 75%        48.100000     37.833300
# max        70.767000    178.017800

# %% [markdown]
# ### *Mean AQI Value is approx. 63
# ### 75th Percentile AQI Value is 69
# ### The most frequently recorded pollutant category is "Good" for all pollutants.

# %%
data.isnull().sum()
# Out:
# Country               273
# City                    0
# AQI Value               0
# AQI Category            0
# CO AQI Value            0
# CO AQI Category         0
# Ozone AQI Value         0
# Ozone AQI Category      0
# NO2 AQI Value           0
# NO2 AQI Category        0
# PM2.5 AQI Value         0
# PM2.5 AQI Category      0
# lat                     0
# lng                     0
# dtype: int64

# %%
data.dropna(axis=1,inplace=True)

# %% [markdown]
# ##  Exploratory Data Analysis

# %%
# Distribution of the AQI Values.

sns.histplot(data["AQI Value"],kde=True)
plt.title("Distribution of AQI Value")
plt.xlabel("AQI Value")
plt.show()

# %%
sns.scatterplot(data=data,x="AQI Value" , y ="PM2.5 AQI Value")
plt.title("AQI Value vs. PM2.5  AQI Value")
plt.xlabel("AQI Value")
plt.show()

# %% [markdown]
# ### *Clearly a  positive correlation between AQI Value and PM2.5 AQI Value

# %%
sns.countplot(data=data,x="AQI Category")
plt.title("Distribution of AQI Categories")
plt.xlabel("AQI Category")
plt.ylabel("Count")
plt.xticks(rotation=45)#This will rotate the x-axis labels by 45 degrees.

plt.show()

# %% [markdown]
# ##  AQI Category vs. AQI Value

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=data,x='AQI Category',y='AQI Value')
plt.title('AQI Category vs. AQI Value')
plt.xlabel('AQI Category')
plt.tight_layout()#To prevent overlapping

plt.show()

# %% [markdown]
# ##  Geographic distribution of cities

# %%
plt.figure(figsize=(12,6))
plt.scatter(data=data,x="lng" , y ="lat", alpha=0.5)
plt.title('Geographic Distribution of Cities')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# ##  Comparison of AQI Categories by Pollutant

# %%
plt.figure(figsize=(14,8))
sns.violinplot(x='AQI Category',y='AQI Value',data=data)
plt.title('Distribution of AQI Categories')
plt.xlabel('"AQI Categories')
plt.ylabel('AQI Value')
plt.show()

# %% [markdown]
# ##  Correlation Matrix of Pollutant AQI Values

# %%
corr_matrix=data[['CO AQI Value','Ozone AQI Value','NO2 AQI Value','PM2.5 AQI Value']].corr()
#.corr() method comes from pandas.

# %%
corr_matrix
# Out:
#                  CO AQI Value  Ozone AQI Value  NO2 AQI Value  PM2.5 AQI Value
# CO AQI Value         1.000000         0.074689       0.434190         0.493505
# Ozone AQI Value      0.074689         1.000000      -0.228611         0.250259
# NO2 AQI Value        0.434190        -0.228611       1.000000         0.340195
# PM2.5 AQI Value      0.493505         0.250259       0.340195         1.000000

# %% [markdown]
# *The correlation matrix shows the relationships between AQI values of different pollutants, including CO, Ozone, NO2, and PM2.5. It helps us understand the degree of association between these pollutants and how they contribute to the overall air quality index

# %% [markdown]
# ##  Plotting a Heatmap

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix,annot=True,vmin=-1,vmax=1)
plt.title('Heatmap of Pollutant AQI Values to show the correlation ')
plt.show()

# %% [markdown]
# ### * Ozone AQI Value has positive correlation with CO AQI Value  whereas negative correlation with NO2 AQI Value

# %% [markdown]
# ##  Scatterplot Matrix of Pollutant AQI Values

# %%
sns.pairplot(data=data,vars=['CO AQI Value','Ozone AQI Value','NO2 AQI Value','PM2.5 AQI Value'],diag_kind='kde')
plt.suptitle("Scatterplot Matrix Of Pollutant AQI Values")  # Adds centered suptitle to the figure.
plt.tight_layout()#Adjust the padding (height/width)between and around subplots.
plt.show()

# %%
data.columns
# Out:
# Index(['City', 'AQI Value', 'AQI Category', 'CO AQI Value', 'CO AQI Category',
#        'Ozone AQI Value', 'Ozone AQI Category', 'NO2 AQI Value',
#        'NO2 AQI Category', 'PM2.5 AQI Value', 'PM2.5 AQI Category', 'lat',
#        'lng'],
#       dtype='object')

# %% [markdown]
# ##  Top Polluted Cities

# %%
# Calculate the average AQI value for each country
country_avg_aqi = data.groupby('City')['AQI Value'].mean().reset_index()    #Applying groupby() function to group the data based on city
                                                                              

# Sort the countries based on average AQI value in descending order
top_polluted_countries = country_avg_aqi.sort_values('AQI Value', ascending=False)

# Display the top polluted countries
print(top_polluted_countries.head(25))
# Out:
#                City  AQI Value
# 907    Bahawalnagar      500.0
# 9958        Pokaran      500.0
# 4847       Hasanpur      500.0
# 7436         Malaut      500.0
# 3268       Dhanaura      500.0
# 3491        Durango      500.0
# 4844      Harunabad      500.0
# 8847          Nohar      500.0
# 10419     Ratangarh      500.0
# 7389   Mahendragarh      500.0
# 3819           Etah      500.0
# 12911         Tynda      500.0
# 7764           Maur      500.0
# 1587       Boksburg      500.0
# 5692        Jodhpur      500.0
# 11175    Sardulgarh      500.0
# 5581      Jalalabad      500.0
# 8612      Nawalgarh      500.0
# 10686        Rohtak      500.0
# 3206          Delhi      500.0
# 9778        Phalodi      500.0
# 9791       Phillaur      444.0
# 2670        Chunian      438.0
# 7418          Makhu      425.0
# 11384         Seoul      421.0

# %%
data.loc[(data['AQI Value']<150) & (data['AQI Value']>101) ]
# Out:
#               City  AQI Value                    AQI Category  CO AQI Value
# 32          Delmas        124  Unhealthy for Sensitive Groups             2  \
# 65         Tianjin        142  Unhealthy for Sensitive Groups             4
# 78           Ilobu        133  Unhealthy for Sensitive Groups             4
# 95     Willowbrook        126  Unhealthy for Sensitive Groups             4
# 99          Xushan        112  Unhealthy for Sensitive Groups             2
# ...            ...        ...                             ...           ...
# 14061      Taiping        131  Unhealthy for Sensitive Groups             3
# 14114       Sparks        138  Unhealthy for Sensitive Groups             3
# 14149     Umarkhed        110  Unhealthy for Sensitive Groups             1
# 14166     Sainthia        120  Unhealthy for Sensitive Groups             3
# 14189         Vinh        105  Unhealthy for Sensitive Groups             4
#
#       CO AQI Category  Ozone AQI Value              Ozone AQI Category
# 32               Good               15                            Good  \
# 65               Good              113  Unhealthy for Sensitive Groups
# 78               Good               23                            Good
# 95               Good                3                            Good
# 99               Good               44                            Good
# ...               ...              ...                             ...
# 14061            Good               24                            Good
# 14114            Good               18                            Good
# 14149            Good               35                            Good
# 14166            Good              108  Unhealthy for Sensitive Groups
# 14189            Good               27                            Good
#
#        NO2 AQI Value NO2 AQI Category  PM2.5 AQI Value
# 32                 5             Good              124  \
# 65                 9             Good              142
# 78                 3             Good              133
# 95                36             Good              126
# 99                 4             Good              112
# ...              ...              ...              ...
# 14061             10             Good              131
# 14114              7             Good              138
# 14149              0             Good              110
# 14166              2             Good              120
# 14189              6             Good              105
#
#                    PM2.5 AQI Category      lat       lng
# 32     Unhealthy for Sensitive Groups  18.5500  -72.3000
# 65     Unhealthy for Sensitive Groups  39.1467  117.2056
# 78     Unhealthy for Sensitive Groups   7.8400    4.4860
# 95     Unhealthy for Sensitive Groups  33.9209 -118.2356
# 99     Unhealthy for Sensitive Groups  30.1697  121.2665
# ...                               ...      ...       ...
# 14061  Unhealthy for Sensitive Groups   4.8500  100.7333
# 14114  Unhealthy for Sensitive Groups  39.5736 -119.7161
# 14149  Unhealthy for Sensitive Groups  19.6000   77.7000
# 14166  Unhealthy for Sensitive Groups  23.9451   87.6803
# 14189  Unhealthy for Sensitive Groups  18.6667  105.6667
#
# [690 rows x 13 columns]

# %% [markdown]
# ### *Precautionary measures needs to be adopted in  the above countries.

# %%
data.loc[(data['AQI Value']>201)]
# Out:
#                City  AQI Value    AQI Category  CO AQI Value CO AQI Category
# 29        Darbhanga        247  Very Unhealthy             3            Good  \
# 53         Hangzhou        203  Very Unhealthy             5            Good
# 127      Govindgarh        307       Hazardous             1            Good
# 180    Bahawalnagar        500       Hazardous             1            Good
# 269        Phillaur        444       Hazardous             2            Good
# ...             ...        ...             ...           ...             ...
# 13529         Tynda        500       Hazardous            21            Good
# 13646     Talagante        251  Very Unhealthy            18            Good
# 13672         Panna        203  Very Unhealthy             1            Good
# 13778       Sagauli        253  Very Unhealthy             4            Good
# 14178  Mian Channun        252  Very Unhealthy             2            Good
#
#        Ozone AQI Value              Ozone AQI Category  NO2 AQI Value
# 29                 162                       Unhealthy              1  \
# 53                 203                  Very Unhealthy              5
# 127                 45                            Good              0
# 180                 38                            Good              1
# 269                111  Unhealthy for Sensitive Groups              1
# ...                ...                             ...            ...
# 13529                8                            Good             17
# 13646                0                            Good             27
# 13672               45                            Good              0
# 13778              166                       Unhealthy              1
# 14178              135  Unhealthy for Sensitive Groups              1
#
#       NO2 AQI Category  PM2.5 AQI Value PM2.5 AQI Category      lat       lng
# 29                Good              247     Very Unhealthy  26.1700   85.9000
# 53                Good              151          Unhealthy  30.2500  120.1675
# 127               Good              307          Hazardous  24.3785   81.2964
# 180               Good              466          Hazardous  29.9928   73.2536
# 269               Good              391          Hazardous  31.0300   75.7800
# ...                ...              ...                ...      ...       ...
# 13529             Good              475          Hazardous  55.1667  124.7167
# 13646             Good              251     Very Unhealthy -33.6667  -70.8667
# 13672             Good              203     Very Unhealthy  24.7200   80.2000
# 13778             Good              253     Very Unhealthy  26.7833   84.7333
# 14178             Good              252     Very Unhealthy  30.4397   72.3544
#
# [161 rows x 13 columns]

# %% [markdown]
# ### There is Health Risk to everyone in the above mentioned countries,  so they need to take strict action against air pollution.

# %% [markdown]
#  Conclusion:
# Based on the exploratory data analysis (EDA) conducted on the provided air quality dataset, the following conclusions can be drawn:
#
# Overall Air Quality: The majority of the recorded AQI values fall within the "Good" to "Moderate" categories, indicating relatively acceptable air quality in many locations. However, there are also instances of higher AQI values, indicating poorer air quality.
#
# Pollutant Contribution: Among the pollutants measured, PM2.5, NO2, CO, and Ozone are the major contributors to air pollution. These pollutants show varying levels of correlation with each other, suggesting potential interactions and shared sources.
#
# Top Polluted Countries: The analysis highlights the countries with consistently poor air quality based on the recorded AQI values. Identifying these countries can aid in directing resources and interventions to improve air quality in those regions.
#
# Geospatial Analysis: Visualizing the geographic distribution of air quality using latitude and longitude coordinates helps identify areas with higher pollution levels. Certain regions may exhibit clusters of polluted areas, indicating localized sources of pollution.
